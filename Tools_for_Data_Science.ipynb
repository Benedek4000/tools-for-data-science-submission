# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Benedek Kovács**
#
# Current Occupation: University Student

# %% [markdown]
# *I'm interested in data science, as I'm like to improve the performance/decisions of a sports team (preferably football or Formula 1)*

# %% [markdown]
# ### The code in Cell 5 is supposed to print "Data Science"

# %%
print("Data Science")
# Out:
# Data Science

# %% [markdown]
# Numbered list:
# 1. Numbered list item 1
# 2. Numbered list item 2
# 3. Numbered list item 3
#
# Bulleted list:
# * Bulleted list item 1
# * Bulleted list item 2
# * Bulleted list item 3
#
# Hyperlink:
#
# [Coursera](https://www.coursera.org/)
